# %%
public class Product {
    private string name;
    private decimal price;
    private int quantity;
    protected string category;
    internal string description;

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.category = category;
        this.description = description;
    }

    public decimal GetTotalPrice() {
        return price*quantity;
    }

    public void UpdateQuantity(int amount)  {
        quantity += amount;
    }

    public string GetProductInfo()
    {
        return $"Имя: {name}, Цена: {price}, Количество: {quantity}, Категория: {category}, Описание: {description}";
    }
}

public class Seller {
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;
    private List<Product> products = new List<Product>(); // коллекция (динамический список), которая хранит набор объектов Product

    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
    }

    public void SellProduct(Product product, int quantity)
    {
        product.UpdateQuantity(-quantity); //уменьшаем количество
    }

    public List<Product> GetProducts()
    {
        return products;
    }

    public string GetSellerInfo() {
        return $"ID: {employeeId}, Имя: {name}, Зарплата: {salary}, Контактные данные: {contactInfo}";
    }
}

public class Store
{
    private string storeName;
    private string location;
    public string storeHours;
    private List<Seller> sellers = new List<Seller>(); //

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
    }

    public void ListProducts()
    {
        Console.WriteLine("Список продуктов:");
        foreach (var seller in sellers)
        {
            foreach (var product in seller.GetProducts())
            {
                Console.WriteLine(product.GetProductInfo());
            }
        }
    }

    public string GetStoreInfo()
    {
        return $"Имя магазина: {storeName}, Улица: {location}, Время работы: {storeHours}";
    }
}

Product product = new Product("Булочка вкусная", 1000.00m, 10, "Выпечка", "Вкусная сладкая сахарная булка");
Product product2 = new Product("Хлеб", 54.00m, 2, "Выпечка","Свежеиспеченный хлеб от бабушки");
Seller seller = new Seller("Васька", "123", 30000.00m, "123@gmail.com");

Console.WriteLine("Общая цена: " + product.GetTotalPrice());

seller.AddProduct(product);
seller.AddProduct(product2);
Console.WriteLine(seller.GetSellerInfo());


Store store = new Store("Ясно", "ул.Мельникайте,70", "Круглосуточно");

store.AddSeller(seller);
Console.WriteLine(store.GetStoreInfo());
store.ListProducts();
seller.SellProduct(product, 2);
store.ListProducts();
# Out:
# Общая цена: 10000.00
# ID: 123, Имя: Васька, Зарплата: 30000.00, Контактные данные: 123@gmail.com
# Имя магазина: Ясно, Улица: ул.Мельникайте,70, Время работы: Круглосуточно
# Список продуктов:
# Имя: Булочка вкусная, Цена: 1000.00, Количество: 10, Категория: Выпечка, Описание: Вкусная сладкая сахарная булка
# Имя: Хлеб, Цена: 54.00, Количество: 2, Категория: Выпечка, Описание: Свежеиспеченный хлеб от бабушки
# Список продуктов:
# Имя: Булочка вкусная, Цена: 1000.00, Количество: 8, Категория: Выпечка, Описание: Вкусная сладкая сахарная булка
# Имя: Хлеб, Цена: 54.00, Количество: 2, Категория: Выпечка, Описание: Свежеиспеченный хлеб от бабушки
